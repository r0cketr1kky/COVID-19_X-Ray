# %% [markdown]
# <a href="https://colab.research.google.com/github/r0cketr1kky/COVID-19_X-Ray/blob/master/boundbox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
arr = cv2.imread('knight.png')

# %%
plt.imshow(arr)

# %%
arr.shape
# Out:
# (100, 104, 3)

# %%
hsv = cv2.cvtColor(arr, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsv)

# %%
import numpy as np

# %%
lower_blue = np.array([20,100,100])
upper_blue = np.array([100,255,255])


# Threshold the HSV image to get only blue colors
mask = cv2.inRange (hsv, lower_blue, upper_blue)

# %%
plt.imshow(mask)

# %%
bluecnts = cv2.findContours(mask.copy(),
                              cv2.RETR_EXTERNAL,
                              cv2.CHAIN_APPROX_SIMPLE)[-2]

# %%
blue_area = max(bluecnts, key=cv2.contourArea)
(xg,yg,wg,hg) = cv2.boundingRect(blue_area)
cv2.rectangle(arr,(xg,yg),(xg+wg, yg+hg),(0,255,0),2)
# Out:
# array([[[ 59,  59,  59],
#         [134,  59, 132],
#         [134,  59, 132],
#         ...,
#         [134,  59, 132],
#         [134,  59, 132],
#         [ 59,  59,  59]],
#
#        [[ 59,  59,  59],
#         [134,  59, 132],
#         [134,  59, 132],
#         ...,
#         [134,  59, 132],
#         [134,  59, 132],
#         [ 59,  59,  59]],
#
#        [[ 59,  59,  59],
#         [134,  59, 132],
#         [134,  59, 132],
#         ...,
#         [134,  59, 132],
#         [134,  59, 132],
#         [ 59,  59,  59]],
#
#        ...,
#
#        [[ 59,  59,  59],
#         [134,  59, 132],
#         [134,  59, 132],
#         ...,
#         [134,  59, 132],
#         [134,  59, 132],
#         [ 59,  59,  59]],
#
#        [[ 59,  59,  59],
#         [134,  59, 132],
#         [134,  59, 132],
#         ...,
#         [134,  59, 132],
#         [134,  59, 132],
#         [ 59,  59,  59]],
#
#        [[ 59,  59,  59],
#         [134,  59, 132],
#         [134,  59, 132],
# ...

# %%
plt.imshow(arr)
